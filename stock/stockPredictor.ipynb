# %%
import pandas
# !pip install yfinance
import yfinance as yf
# Out:
# Requirement already satisfied: yfinance in c:\code\git\stock\.venv\lib\site-packages (0.2.37)
# Requirement already satisfied: pandas>=1.3.0 in c:\code\git\stock\.venv\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\code\git\stock\.venv\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\code\git\stock\.venv\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\code\git\stock\.venv\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\code\git\stock\.venv\lib\site-packages (from yfinance) (5.2.1)
# Requirement already satisfied: appdirs>=1.4.4 in c:\code\git\stock\.venv\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\code\git\stock\.venv\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\code\git\stock\.venv\lib\site-packages (from yfinance) (2.4.1)
# Requirement already satisfied: peewee>=3.16.2 in c:\code\git\stock\.venv\lib\site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\code\git\stock\.venv\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\code\git\stock\.venv\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\code\git\stock\.venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\code\git\stock\.venv\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\code\git\stock\.venv\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\code\git\stock\.venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\code\git\stock\.venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\code\git\stock\.venv\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\code\git\stock\.venv\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\code\git\stock\.venv\lib\site-packages (from requests>=2.31->yfinance) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\code\git\stock\.venv\lib\site-packages (from requests>=2.31->yfinance) (2024.2.2)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
sp500 = yf.Ticker("^GSPC")

# %%
sp500 = sp500.history(period="max")

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2024-04-01 00:00:00-04:00', '2024-04-02 00:00:00-04:00',
#                '2024-04-03 00:00:00-04:00', '2024-04-04 00:00:00-04:00',
#                '2024-04-05 00:00:00-04:00', '2024-04-08 00:00:00-04:00',
#                '2024-04-09 00:00:00-04:00', '2024-04-10 00:00:00-04:00',
#                '2024-04-11 00:00:00-04:00', '2024-04-12 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24186, freq=None)

# %%
# !pip install matplotlib
sp500.plot.line(y="Close", use_index=True)
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\code\git\stock\.venv\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\code\git\stock\.venv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\code\git\stock\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\code\git\stock\.venv\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\code\git\stock\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\code\git\stock\.venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\code\git\stock\.venv\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\code\git\stock\.venv\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\code\git\stock\.venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\code\git\stock\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\code\git\stock\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# <Axes: xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-04-08 00:00:00-04:00  5211.370117  5219.569824  5197.350098  5202.390137
# 2024-04-09 00:00:00-04:00  5217.029785  5224.810059  5160.779785  5209.910156
# 2024-04-10 00:00:00-04:00  5167.879883  5178.430176  5138.700195  5160.640137
# 2024-04-11 00:00:00-04:00  5172.950195  5211.779785  5138.770020  5199.060059
# 2024-04-12 00:00:00-04:00  5171.509766  5175.029785  5107.939941  5123.410156
#
#                                Volume     Tomorrow
# Date
# 1927-12-30 00:00:00-05:00           0    17.760000
# 1928-01-03 00:00:00-05:00           0    17.719999
# 1928-01-04 00:00:00-05:00           0    17.549999
# 1928-01-05 00:00:00-05:00           0    17.660000
# 1928-01-06 00:00:00-05:00           0    17.500000
# ...                               ...          ...
# 2024-04-08 00:00:00-04:00  3278180000  5209.910156
# 2024-04-09 00:00:00-04:00  3400680000  5160.640137
# 2024-04-10 00:00:00-04:00  3845930000  5199.060059
# 2024-04-11 00:00:00-04:00  3509380000  5123.410156
# 2024-04-12 00:00:00-04:00  2409339000          NaN
#
# [24186 rows x 6 columns]

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-04-08 00:00:00-04:00  5211.370117  5219.569824  5197.350098  5202.390137
# 2024-04-09 00:00:00-04:00  5217.029785  5224.810059  5160.779785  5209.910156
# 2024-04-10 00:00:00-04:00  5167.879883  5178.430176  5138.700195  5160.640137
# 2024-04-11 00:00:00-04:00  5172.950195  5211.779785  5138.770020  5199.060059
# 2024-04-12 00:00:00-04:00  5171.509766  5175.029785  5107.939941  5123.410156
#
#                                Volume     Tomorrow  Target
# Date
# 1927-12-30 00:00:00-05:00           0    17.760000       1
# 1928-01-03 00:00:00-05:00           0    17.719999       0
# 1928-01-04 00:00:00-05:00           0    17.549999       0
# 1928-01-05 00:00:00-05:00           0    17.660000       1
# 1928-01-06 00:00:00-05:00           0    17.500000       0
# ...                               ...          ...     ...
# 2024-04-08 00:00:00-04:00  3278180000  5209.910156       1
# 2024-04-09 00:00:00-04:00  3400680000  5160.640137       0
# 2024-04-10 00:00:00-04:00  3845930000  5199.060059       1
# 2024-04-11 00:00:00-04:00  3509380000  5123.410156       0
# 2024-04-12 00:00:00-04:00  2409339000          NaN       0
#
# [24186 rows x 7 columns]

# %%
sp500 = sp500.loc["1990-01-01":].copy()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2024-04-08 00:00:00-04:00  5211.370117  5219.569824  5197.350098  5202.390137
# 2024-04-09 00:00:00-04:00  5217.029785  5224.810059  5160.779785  5209.910156
# 2024-04-10 00:00:00-04:00  5167.879883  5178.430176  5138.700195  5160.640137
# 2024-04-11 00:00:00-04:00  5172.950195  5211.779785  5138.770020  5199.060059
# 2024-04-12 00:00:00-04:00  5171.509766  5175.029785  5107.939941  5123.410156
#
#                                Volume     Tomorrow  Target
# Date
# 1990-01-02 00:00:00-05:00   162070000   358.760010       0
# 1990-01-03 00:00:00-05:00   192330000   355.670013       0
# 1990-01-04 00:00:00-05:00   177000000   352.200012       0
# 1990-01-05 00:00:00-05:00   158530000   353.790009       1
# 1990-01-08 00:00:00-05:00   140110000   349.619995       0
# ...                               ...          ...     ...
# 2024-04-08 00:00:00-04:00  3278180000  5209.910156       1
# 2024-04-09 00:00:00-04:00  3400680000  5160.640137       0
# 2024-04-10 00:00:00-04:00  3845930000  5199.060059       1
# 2024-04-11 00:00:00-04:00  3509380000  5123.410156       0
# 2024-04-12 00:00:00-04:00  2409339000          NaN       0
#
# [8636 rows x 7 columns]

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\code\git\stock\.venv\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\code\git\stock\.venv\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\code\git\stock\.venv\lib\site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\code\git\stock\.venv\lib\site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\code\git\stock\.venv\lib\site-packages (from scikit-learn) (3.4.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=1000, min_samples_split=100, random_state=1)

train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, n_estimators=1000, random_state=1)

# %%
train
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2023-11-10 00:00:00-05:00  4364.149902  4418.029785  4353.339844  4415.240234
# 2023-11-13 00:00:00-05:00  4406.660156  4421.759766  4393.819824  4411.549805
# 2023-11-14 00:00:00-05:00  4458.970215  4508.669922  4458.970215  4495.700195
# 2023-11-15 00:00:00-05:00  4505.299805  4521.169922  4495.310059  4502.879883
# 2023-11-16 00:00:00-05:00  4497.080078  4511.990234  4487.830078  4508.240234
#
#                                Volume     Tomorrow  Target
# Date
# 1990-01-02 00:00:00-05:00   162070000   358.760010       0
# 1990-01-03 00:00:00-05:00   192330000   355.670013       0
# 1990-01-04 00:00:00-05:00   177000000   352.200012       0
# 1990-01-05 00:00:00-05:00   158530000   353.790009       1
# 1990-01-08 00:00:00-05:00   140110000   349.619995       0
# ...                               ...          ...     ...
# 2023-11-10 00:00:00-05:00  3665080000  4411.549805       0
# 2023-11-13 00:00:00-05:00  3326240000  4495.700195       1
# 2023-11-14 00:00:00-05:00  4700350000  4502.879883       1
# 2023-11-15 00:00:00-05:00  4347170000  4508.240234       1
# 2023-11-16 00:00:00-05:00  3964520000  4514.020020       1
#
# [8536 rows x 7 columns]

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
import pandas as pd

# %%
preds = pd.Series(preds, index = test.index)

# %%
preds
# Out:
# Date
# 2023-11-17 00:00:00-05:00    1
# 2023-11-20 00:00:00-05:00    1
# 2023-11-21 00:00:00-05:00    1
# 2023-11-22 00:00:00-05:00    0
# 2023-11-24 00:00:00-05:00    0
#                             ..
# 2024-04-08 00:00:00-04:00    0
# 2024-04-09 00:00:00-04:00    0
# 2024-04-10 00:00:00-04:00    0
# 2024-04-11 00:00:00-04:00    0
# 2024-04-12 00:00:00-04:00    0
# Length: 100, dtype: int32

# %%
precision_score(test["Target"], preds)
# Out:
# 0.6428571428571429

# %%
combined = pd.concat([test["Target"], preds], axis = 1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index = test.index, name = "Predictions")
    combined = pd.concat([test["Target"], preds], axis = 1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step = 250):
    all_predictions = []
    
    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy();
        test = data.iloc[i:(i+step)].copy();
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions);

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    3499
# 1    2637
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5305271141448615

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.53455
# 0    0.46545
# Name: count, dtype: float64

# %%
horizons = [2,5,60,250,1000]
new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()
    
    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]
    
    trend_column = f"Trend_{horizon}"
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]
    
    new_predictors += [ratio_column, trend_column]

# %%
sp500 = sp500.dropna()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1993-12-14 00:00:00-05:00   465.730011   466.119995   462.459991   463.059998
# 1993-12-15 00:00:00-05:00   463.059998   463.690002   461.839996   461.839996
# 1993-12-16 00:00:00-05:00   461.859985   463.980011   461.859985   463.339996
# 1993-12-17 00:00:00-05:00   463.339996   466.380005   463.339996   466.380005
# 1993-12-20 00:00:00-05:00   466.380005   466.899994   465.529999   465.850006
# ...                                ...          ...          ...          ...
# 2024-04-05 00:00:00-04:00  5158.950195  5222.180176  5157.209961  5204.339844
# 2024-04-08 00:00:00-04:00  5211.370117  5219.569824  5197.350098  5202.390137
# 2024-04-09 00:00:00-04:00  5217.029785  5224.810059  5160.779785  5209.910156
# 2024-04-10 00:00:00-04:00  5167.879883  5178.430176  5138.700195  5160.640137
# 2024-04-11 00:00:00-04:00  5172.950195  5211.779785  5138.770020  5199.060059
#
#                                Volume     Tomorrow  Target  Close_Ratio_2  \
# Date
# 1993-12-14 00:00:00-05:00   275050000   461.839996       0       0.997157
# 1993-12-15 00:00:00-05:00   331770000   463.339996       1       0.998681
# 1993-12-16 00:00:00-05:00   284620000   466.380005       1       1.001621
# 1993-12-17 00:00:00-05:00   363750000   465.850006       0       1.003270
# 1993-12-20 00:00:00-05:00   255900000   465.299988       0       0.999431
# ...                               ...          ...     ...            ...
# 2024-04-05 00:00:00-04:00  3386780000  5202.390137       0       1.005519
# 2024-04-08 00:00:00-04:00  3278180000  5209.910156       1       0.999813
# 2024-04-09 00:00:00-04:00  3400680000  5160.640137       0       1.000722
# 2024-04-10 00:00:00-04:00  3845930000  5199.060059       1       0.995249
# 2024-04-11 00:00:00-04:00  3509380000  5123.410156       0       1.003709
#
#                            Trend_2  Close_Ratio_5  Trend_5  Close_Ratio_60  \
# Date
# 1993-12-14 00:00:00-05:00      1.0       0.996617      1.0        1.000283
# 1993-12-15 00:00:00-05:00      0.0       0.995899      1.0        0.997329
# 1993-12-16 00:00:00-05:00      1.0       0.999495      2.0        1.000311
# 1993-12-17 00:00:00-05:00      2.0       1.004991      3.0        1.006561
# 1993-12-20 00:00:00-05:00      1.0       1.003784      2.0        1.005120
# ...                            ...            ...      ...             ...
# 2024-04-05 00:00:00-04:00      1.0       1.000349      2.0        1.033277
# 2024-04-08 00:00:00-04:00      1.0       1.001568      2.0        1.031460
# 2024-04-09 00:00:00-04:00      1.0       1.002857      3.0        1.031486
# 2024-04-10 00:00:00-04:00      1.0       0.995321      2.0        1.020463
# 2024-04-11 00:00:00-04:00      1.0       1.000730      3.0        1.026595
#
#                            Trend_60  Close_Ratio_250  Trend_250  \
# Date
# 1993-12-14 00:00:00-05:00      32.0         1.028047      127.0
# 1993-12-15 00:00:00-05:00      32.0         1.025151      126.0
# 1993-12-16 00:00:00-05:00      32.0         1.028274      127.0
# 1993-12-17 00:00:00-05:00      32.0         1.034781      128.0
# 1993-12-20 00:00:00-05:00      32.0         1.033359      128.0
# ...                             ...              ...        ...
# 2024-04-05 00:00:00-04:00      34.0         1.144248      138.0
# 2024-04-08 00:00:00-04:00      33.0         1.142721      137.0
# 2024-04-09 00:00:00-04:00      34.0         1.143267      138.0
# 2024-04-10 00:00:00-04:00      33.0         1.131393      138.0
# 2024-04-11 00:00:00-04:00      34.0         1.138765      138.0
#
#                            Close_Ratio_1000  Trend_1000
# Date
# 1993-12-14 00:00:00-05:00          1.176082       512.0
# 1993-12-15 00:00:00-05:00          1.172676       512.0
# 1993-12-16 00:00:00-05:00          1.176163       513.0
# 1993-12-17 00:00:00-05:00          1.183537       514.0
# 1993-12-20 00:00:00-05:00          1.181856       513.0
# ...                                     ...         ...
# 2024-04-05 00:00:00-04:00          1.267798       533.0
# 2024-04-08 00:00:00-04:00          1.266581       532.0
# 2024-04-09 00:00:00-04:00          1.267691       532.0
# 2024-04-10 00:00:00-04:00          1.254989       532.0
# 2024-04-11 00:00:00-04:00          1.263576       533.0
#
# [7635 rows x 17 columns]

# %%
model = RandomForestClassifier(n_estimators = 1000, min_samples_split = 50, random_state = 1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >= 0.6] = 1
    preds[preds < 0.6] = 0
    preds = pd.Series(preds, index = test.index, name = "Predictions")
    combined = pd.concat([test["Target"], preds], axis = 1)
    return combined

# %%
combined
# Out:
#                            Target  0
# Date
# 2023-11-17 00:00:00-05:00       1  1
# 2023-11-20 00:00:00-05:00       0  1
# 2023-11-21 00:00:00-05:00       1  1
# 2023-11-22 00:00:00-05:00       1  0
# 2023-11-24 00:00:00-05:00       0  0
# ...                           ... ..
# 2024-04-08 00:00:00-04:00       1  0
# 2024-04-09 00:00:00-04:00       0  0
# 2024-04-10 00:00:00-04:00       1  0
# 2024-04-11 00:00:00-04:00       0  0
# 2024-04-12 00:00:00-04:00       0  0
#
# [100 rows x 2 columns]

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions["Predictions"].value_counts()

# %%
precision_score(predictions["Target"], predictions["Predictions"])

# %%
train

# %%
today = pd.to_datetime('today').normalize()

# %%
import pickle
with open('sp500_model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
predictions
